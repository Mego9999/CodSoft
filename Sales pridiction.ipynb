# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import make_scorer, mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import category_encoders as ce
from sklearn.decomposition import PCA
from category_encoders import TargetEncoder
import pickle

# %%
df=pd.read_csv('advertising.csv')
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.shape
# Out:
# (200, 4)

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
x=df.drop(columns='Sales')
y=df['Sales']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (140, 3)
# (140,)
# (60, 3)
# (60,)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)
print(y_pred.shape)
# Out:
# (60,)

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# Mean Absolute Error (MAE): 1.16
# Mean Squared Error (MSE): 2.54
# R² Score: 0.91

# %%
lr=SVR()
lr.fit(x_train,y_train)
y_pred = lr.predict(x_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# Mean Absolute Error (MAE): 1.58
# Mean Squared Error (MSE): 3.82
# R² Score: 0.86

# %%
model = Sequential([
    Dense(64, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(1)  # Output layer for regression
])

model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
history = model.fit(x_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)
y_pred = model.predict(x_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# Epoch 1/50
# C:\Users\muham\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 757.2958 - val_loss: 96.2572
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 84.9847 - val_loss: 47.4296
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 85.1573 - val_loss: 117.1347
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 122.6053 - val_loss: 57.1233
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 60.5158 - val_loss: 10.8722
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.2377 - val_loss: 17.7476
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.8253 - val_loss: 23.2829
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.4455 - val_loss: 11.5089
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.3937 - val_loss: 7.6952
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.8757 - val_loss: 12.3008
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.3373 - val_loss: 10.2309
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.1630 - val_loss: 6.2934
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3731 - val_loss: 6.9947
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5185 - val_loss: 6.6617
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2141 - val_loss: 5.7261
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.0221 - val_loss: 6.0522
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5063 - val_loss: 5.6101
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6349 - val_loss: 5.1089
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2842 - val_loss: 5.2641
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7831 - val_loss: 4.8853
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1555 - val_loss: 4.7353
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4863 - val_loss: 4.6280
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2517 - val_loss: 4.7039
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8103 - val_loss: 4.6361
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4553 - val_loss: 4.4141
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6841 - val_loss: 4.3277
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2714 - val_loss: 4.2173
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0483 - val_loss: 4.5678
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.8855 - val_loss: 4.2629
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9431 - val_loss: 4.1408
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9512 - val_loss: 4.0762
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5557 - val_loss: 4.1766
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5171 - val_loss: 4.0982
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7012 - val_loss: 3.9907
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7562 - val_loss: 3.9243
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9782 - val_loss: 3.9534
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0673 - val_loss: 3.9913
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0520 - val_loss: 3.8802
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9924 - val_loss: 3.8427
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6016 - val_loss: 3.9377
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8603 - val_loss: 4.1109
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1374 - val_loss: 3.8432
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6304 - val_loss: 3.8520
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5732 - val_loss: 3.8949
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4239 - val_loss: 3.9131
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6483 - val_loss: 3.8741
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4720 - val_loss: 3.8749
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5772 - val_loss: 3.9231
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4068 - val_loss: 3.8475
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6170 - val_loss: 3.8065
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Mean Absolute Error (MAE): 1.98
# Mean Squared Error (MSE): 6.41
# R² Score: 0.77

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_data, columns=df.columns)
x=scaled_df.drop(columns='Sales')
y=scaled_df['Sales']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
lr=SVR()
lr.fit(x_train,y_train)
y_pred = lr.predict(x_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# Mean Absolute Error (MAE): 0.25
# Mean Squared Error (MSE): 0.11
# R² Score: 0.89

# %%
model = Sequential([
    Dense(64, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(1)  # Output layer for regression
])

model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
history = model.fit(x_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)
y_pred = model.predict(x_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# Epoch 1/50
# C:\Users\muham\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 1.0834 - val_loss: 1.0286
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7779 - val_loss: 0.8222
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6518 - val_loss: 0.6613
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4203 - val_loss: 0.5258
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3192 - val_loss: 0.4094
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2204 - val_loss: 0.3134
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1536 - val_loss: 0.2392
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1338 - val_loss: 0.1872
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1067 - val_loss: 0.1514
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0955 - val_loss: 0.1312
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0936 - val_loss: 0.1187
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0802 - val_loss: 0.1128
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0791 - val_loss: 0.1110
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0733 - val_loss: 0.1119
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0844 - val_loss: 0.1148
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0738 - val_loss: 0.1190
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0687 - val_loss: 0.1219
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0764 - val_loss: 0.1235
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0674 - val_loss: 0.1239
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0720 - val_loss: 0.1228
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0713 - val_loss: 0.1218
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0516 - val_loss: 0.1205
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0690 - val_loss: 0.1216
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0643 - val_loss: 0.1216
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0547 - val_loss: 0.1216
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0612 - val_loss: 0.1218
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0701 - val_loss: 0.1227
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0501 - val_loss: 0.1222
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0588 - val_loss: 0.1230
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0550 - val_loss: 0.1234
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0534 - val_loss: 0.1238
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0566 - val_loss: 0.1236
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0541 - val_loss: 0.1242
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0554 - val_loss: 0.1241
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0582 - val_loss: 0.1234
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0532 - val_loss: 0.1237
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0588 - val_loss: 0.1226
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0529 - val_loss: 0.1226
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0514 - val_loss: 0.1222
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0571 - val_loss: 0.1239
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0446 - val_loss: 0.1234
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0517 - val_loss: 0.1244
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0535 - val_loss: 0.1275
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0496 - val_loss: 0.1272
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0575 - val_loss: 0.1267
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0588 - val_loss: 0.1273
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0537 - val_loss: 0.1295
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0435 - val_loss: 0.1289
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0496 - val_loss: 0.1283
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0408 - val_loss: 0.1292
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Mean Absolute Error (MAE): 0.24
# Mean Squared Error (MSE): 0.09
# R² Score: 0.91
